# %%
from sklearn.datasets import load_iris
import pandas as pd
from pandas import DataFrame as df

# %% [markdown]
# <h1>PROBLEM 1</h1>

# %%
iris_ds = load_iris()

x = df(iris_ds.data, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
y = df(iris_ds.target, columns=['Species'])
print(x)
print(y)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %% [markdown]
# <h1>PROBLEM 2</h1>

# %%
dataframe = pd.concat([x, y], axis=1)
dataframe
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# <h1>PROBLEM 3</h1>

# %%
# Display the 4th sample from the beginning and see what each feature is like.
print("4th Sample:")
print(dataframe.head(4).iloc[3])  # Displaying the 4th sample (index 3)

# Output the total number of samples for each label.
print("\nTotal number of samples for each label:")
print(dataframe['Species'].value_counts())

# Check if there is a missing value in the feature quantity.
print("\nChecking for missing values:")
print(dataframe.isnull().sum())

# Display the mean, standard deviation, and quartiles of the feature values at once.
print("\nSummary Statistics:")
print(dataframe.describe())
# Out:
# 4th Sample:
# sepal_length    4.6
# sepal_width     3.1
# petal_length    1.5
# petal_width     0.2
# Species         0.0
# Name: 3, dtype: float64
#
# Total number of samples for each label:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64
#
# Checking for missing values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Species         0
# dtype: int64
#
# Summary Statistics:
#        sepal_length  sepal_width  petal_length  petal_width     Species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# ...

# %% [markdown]
# <h1>PROBLEM 4</h1>

# %% [markdown]
# <h1>PROBLEM 5</h1>

# %%
#Extract the sepal_width column in two different ways
dataframe1a = dataframe[['sepal_width']]
dataframe1b = dataframe.sepal_width
print(f'''
Extract the sepal_width column in two different ways
first way:
{dataframe1a}
second way:
{dataframe1b}
      ''')
# Out:
# Extract the sepal_width column in two different ways
# first way:
#      sepal_width
# 0            3.5
# 1            3.0
# 2            3.2
# 3            3.1
# 4            3.6
# ..           ...
# 145          3.0
# 146          2.5
# 147          3.0
# 148          3.4
# 149          3.0
#
# [150 rows x 1 columns]
# second way:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
#Extract the 50th to 99th data​
dataframe2 = dataframe.iloc[50:100]
dataframe2
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
# 53           5.5          2.3           4.0          1.3        1
# 54           6.5          2.8           4.6          1.5        1
# 55           5.7          2.8           4.5          1.3        1
# 56           6.3          3.3           4.7          1.6        1
# 57           4.9          2.4           3.3          1.0        1
# 58           6.6          2.9           4.6          1.3        1
# 59           5.2          2.7           3.9          1.4        1
# 60           5.0          2.0           3.5          1.0        1
# 61           5.9          3.0           4.2          1.5        1
# 62           6.0          2.2           4.0          1.0        1
# ...

# %%
#Extract the 50th to 99th data of the petal_length column
dataframe3 = dataframe[['petal_length']].iloc[50:100]
print(f'''
50th to 99th data of the petal_length column:
{dataframe3}
      ''')
# Out:
# 50th to 99th data of the petal_length column:
#     petal_length
# 50           4.7
# 51           4.5
# 52           4.9
# 53           4.0
# 54           4.6
# 55           4.5
# 56           4.7
# 57           3.3
# 58           4.6
# 59           3.9
# 60           3.5
# 61           4.2
# 62           4.0
# 63           4.7
# 64           3.6
# 65           4.4
# 66           4.5
# 67           4.1
# 68           4.5
# 69           3.9
# 70           4.8
# 71           4.0
# 72           4.9
# 73           4.7
# 74           4.3
# 75           4.4
# 76           4.8
# 77           5.0
# 78           4.5
# 79           3.5
# 80           3.8
# 81           3.7
# 82           3.9
# 83           5.1
# 84           4.5
# 85           4.5
# 86           4.7
# 87           4.4
# 88           4.1
# 89           4.0
# 90           4.4
# 91           4.6
# 92           4.0
# 93           3.3
# 94           4.2
# 95           4.2
# 96           4.2
# 97           4.3
# 98           3.0
# ...

# %%
#Extract data with a petal_width value of 0.2​
dataframe4 = dataframe[dataframe['petal_width'] == 0.2]
dataframe4
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0
# 7            5.0          3.4           1.5          0.2        0
# 8            4.4          2.9           1.4          0.2        0
# 10           5.4          3.7           1.5          0.2        0
# 11           4.8          3.4           1.6          0.2        0
# 14           5.8          4.0           1.2          0.2        0
# 20           5.4          3.4           1.7          0.2        0
# 22           4.6          3.6           1.0          0.2        0
# 24           4.8          3.4           1.9          0.2        0
# ...

# %% [markdown]
# <h1>PROBLEM 6</h1>

# %%
import matplotlib.pyplot as plt

# %%
#Make a pie chart of the number of samples per label (while showing percentages)
labels = ['0', '1', '2']
total = dataframe.Species.sum()
number0 = (dataframe['Species'].value_counts()[0]) * 100 / total
number1 = (dataframe['Species'].value_counts()[1]) * 100 / total
number2 = (dataframe['Species'].value_counts()[2]) * 100 / total
values = [number0, number1, number2]

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=0)
plt.title('Pie Chart')
plt.show()

# %%
#Select features one by one and visualize the distribution of data for each label using a box plot
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 5))


dataframe.boxplot(column='sepal_length', ax=axes[0])
axes[0].set_title('Sepal Length')

dataframe.boxplot(column='sepal_width', ax=axes[1])
axes[1].set_title('Sepal Width')

dataframe.boxplot(column='petal_length', ax=axes[2])
axes[2].set_title('Petal Length')

dataframe.boxplot(column='petal_width', ax=axes[3])
axes[3].set_title('Petal Width')
# Out:
# Text(0.5, 1.0, 'Petal Width')

# %%
import seaborn as sns

#Select features one by one and visualize the distribution of data for each label using a violin plot
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 5))


sns.violinplot(x='Species', y='sepal_length', data=dataframe, ax=axes[0])
axes[0].set_title('Sepal Length')

sns.violinplot(x='Species', y='sepal_width', data=dataframe, ax=axes[1])
axes[1].set_title('Sepal Width')

sns.violinplot(x='Species', y='petal_length', data=dataframe, ax=axes[2])
axes[2].set_title('Petal Length')

sns.violinplot(x='Species', y='petal_width', data=dataframe, ax=axes[3])
axes[3].set_title('Petal Width')


plt.suptitle('Violin Plots of Iris Dataset', y=1.02)
plt.tight_layout()
plt.show()
